# %% [markdown]
# ## Datatypes
#
# 1. Definition:
# Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
# They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# 2. Importance of Data Types in Programming
# Explanation:
#
# Data types ensure that data is stored in an efficient way.
# They help in performing correct operations on data.
# Proper use of data types can prevent errors and bugs in the program.

# %%
age = 35
type(age)
# Out:
# int

# %%
height= 6.1
print(height)
print(type(height))
# Out:
# 6.1
# <class 'float'>

# %%
## string datatype
name = "aditya"
print(name)
print(type(name))
# Out:
# aditya
# <class 'str'>

# %%
##Boolean datatype
is_student = True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
a = 10
b = 10
print(a == b)  # True, because a and b are equal
print(a is b)  # True, because a and b point to the same object in
# Out:
# True
# True

# %%
result='Hello' + str(5)  # Corrected to convert integer to string before concatenation
print(result)  # This will now print "Hello5" without raising an error
# Out:
# Hello5
