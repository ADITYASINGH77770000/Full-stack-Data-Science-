# %%
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(25))
print(sqrt(16))
print(pi)
# Out:
# 5.0
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sqrt(36))
print(pi)
# Out:
# 6.0
# 3.141592653589793
